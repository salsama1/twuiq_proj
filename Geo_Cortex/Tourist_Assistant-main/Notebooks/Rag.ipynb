# %%
import bs4
from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.document_loaders import 
from langchain.document_loaders import WebBaseLoader
from langchain.vectorstores import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings


# Load blog post
loader = WebBaseLoader("https://lilianweng.github.io/posts/2023-06-23-agent/")
data = loader.load()

# Split
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)
splits = text_splitter.split_documents(data)

# VectorDB
embedding = OpenAIEmbeddings()
vectordb = FAISS.from_documents(documents=splits, embedding=embedding)
# Out:
#   Cell In[1], line 4
#     from langchain_core.document_loaders import
#                                                 ^
# SyntaxError: invalid syntax

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI


# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(model="gpt-4o-mini", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)
# Out:
# Hello! Welcome! I’m glad you reached out. How can I assist you today?

# %%
# A class to represent a Webpage
# If you're not familiar with Classes, check out the "Intermediate Python" notebook

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# Let's try one out. Change the website and add print statements to follow along.

ed = Website("https://www.experienceegypt.eg//en/home/about")
print(ed.title)
print(ed.text)
# Out:
#             Experience Egypt
#
# ABOUT EGYPT
# The land where it all begins
# This is Egypt
# Geography
# History
# Language & culture
# WHERE TO GO
# Find Your Dream Destination
# The Nile
# Learn more
# The Red Sea
# Learn more
# The Med
# Learn more
# DESERTS & OASES
# Learn more
# WHAT TO DO
# Get Ready for the Experience of a Lifetime
# SUN & SEA
# ARCHEOLOGICAL SITES
# SPIRITUAL EGYPT
# MUSEUMS
# CRUISING & SAILING
# ADVENTURE & OUTDOOR
# ECOTOURISM & NATURE
# HEALTH & WELLNESS
# ARTS & CONTEMPORARY CULTURE
# WHAT'S ON
# Upcoming  Events
# Alex Short Film Festival
# 27
# Apr
# Aswan International Women Film
# 2
# May
# Eye on Egypt
# Visiting The Temples Of Luxor? Stop By The Colossi Of Memnon
# Read More
# Culture And Beach Holidays In Egypt
# Read More
# USEFUL INFORMATION
# Good to Know
# Entry visa
# PLAN YOUR TRIP
# PRACTICAL INFO
# TRAVEL SAFE
# GETTING AROUND
# HOW TO GET THERE
# USEFUL NUMBERS
# ABOUT EGYPT
# - THIS IS EGYPT
# - GEOGRAPHY
# - HISTORY
# - LANGUAGE & CULTURE
# WHERE TO GO
# - THE NILE
# - THE RED SEA
# - THE MED
# - DESERTS & OASES
# WHAT TO DO
# - SUN & SEA
# - ARCHEOLOGICAL SITES
# - SPIRITUAL EGYPT
# - MUSEUMS
# - CRUISING & SAILING
# - ADVENTURE & OUTDOOR
# - ECOTOURISM & NATURE
# - HEALTH & WELLNESS
# - ARTS & CONTEMPORARY CULTURE
# WHAT'S ON
# - EVENTS
# - NEWS
# USEFUL INFORMATION
# ENTRY VISA
# PLAN YOUR TRIP
# PRACTICAL INFO
# TRAVEL SAFE
# GETTING AROUND
# HOW TO GET THERE
# USEFUL NUMBERS
# English
# English
# 中文
# Deutsch
# Русский
# Recommended Places
# Sharm El-Sheikh
# Home
# This is Egypt
# ABOUT EGYPT
# Discover the Warmth of Egypt & Make Lifelong Memories
# A life well-travelled cannot be considered complete without at least one visit to
#                         Egypt! Egypt isn’t just home to the oldest and best-preserved historical sites on earth, the
#                         country offers diverse holiday experiences catered to your travel preferences. You can enjoy an
#                         immersive urban experience in Cairo and Alexandria, discover some of the best snorkeling and
#                         scuba diving sites in the world in the Red Sea, get a taste of life on the Nile on personalized
#                         Nile cruises, or curate your own desert adventure. The energy, hospitality, and good humor of
#                         the Egyptian people are at the heart of any visit to Egypt, with sunny smiles etched onto the
#                         faces of nearly every person you will encounter. Expect multiple offers for homecooked meals,
#                         invites to weddings and parties, and a chance to make new friends as warm as the golden Egyptian
#                         sun.
# Geography
# From the River Nile to the splendor of our vast deserts, and from the
#                                 glistening waters at beaches to the rugged mountains, discover what the diverse
#                                 landscapes of Egypt have to offer.
# History
# You’ve heard about the Great Pyramids of Giza, but Egypt has much more
#                                 magic and mystique to offer. The vastness and diversity of our history will inspire you.
# Population, Language & Culture
# The first thing you will notice is the warmth and hospitality of our
#                                 people. Come and discover the richness of our way of
#                                 life.
# Fun Facts
# 103 million
# the population of Egypt with youth representing around 60%
# 3,800 +
# hours of sun/year
# 21 million +
# the population of Cairo, one of the world’s largest cities
# 2,629 m
# the height of Mount Catherine in Sinai, the highest point in Egypt
# 3,800 sq km
# of coral reefs in Egypt’s Red Sea
# 7,000 sq km
# of marine protected areas
# 2,900 km
# of coastline
# 525 ha
# of mangrove forests
# 750 +
# species of fish in Egypt’s waters
# 490 +
# Species of birds in Egypt
# 300 - 350
# species of migrating birds throughout the year
# 93%
# of the total land area of Egypt is desert
# Subscribe to the Ministry's News Letter
# Follow us:
# Popular links
# About Egypt
# Where to go
# what to do
# Whats's on
# Media Kit
# Helpful information
# Plan Your Trip
# Visa guide
# Practical Info
# Travel Safe
# Getting Around
# How to Get There
# Useful Numbers
# Related sites
# Grand Egyptian Museum
# The National Museum of Egyptian Civilization
# Museum of Islamic Art
# The Egyptian Museum
# Visa2egypt
# Yacht Single Window
# Useful Links
# Tickets & Souvenirs
# Contact Us
# ALL RIGHTS RESERVED© 2025
# Official Promotional website
# Egyptian Tourism Authority
# Ministry of Tourism and Antiquities
# Arab Republic of Egypt

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an tour guide assistant that analyzes the contents of egypt website \
and provides list of activeties, ignoring text that might be navigation related. \
Respond in markdown list ."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a  list of activeties, in markdown list. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(ed))
# Out:
# You are looking at a website titled
#             Experience Egypt
#
# The contents of this website is as follows; please provide a  list of activeties, in markdown list. If it includes news or announcements, then summarize these too.
#
# ABOUT EGYPT
# The land where it all begins
# This is Egypt
# Geography
# History
# Language & culture
# WHERE TO GO
# Find Your Dream Destination
# The Nile
# Learn more
# The Red Sea
# Learn more
# The Med
# Learn more
# DESERTS & OASES
# Learn more
# WHAT TO DO
# Get Ready for the Experience of a Lifetime
# SUN & SEA
# ARCHEOLOGICAL SITES
# 750 +
# species of fish in Egypt’s waters
# 490 +
# Species of birds in Egypt
# 300 - 350
# species of migrating birds throughout the year
# 93%
# of the total land area of Egypt is desert
# Subscribe to the Ministry's News Letter
# Follow us:
# Popular links
# About Egypt
# Where to go
# what to do
# Whats's on
# Media Kit
# Helpful information
# Plan Your Trip
# Visa guide
# Practical Info
# Travel Safe
# Getting Around
# How to Get There
# Useful Numbers
# Related sites
# Grand Egyptian Museum
# The National Museum of Egyptian Civilization
# Museum of Islamic Art
# The Egyptian Museum
# Visa2egypt
# Yacht Single Window
# Useful Links
# Tickets & Souvenirs
# Contact Us
# ALL RIGHTS RESERVED© 2025
# Official Promotional website
# Egyptian Tourism Authority
# Ministry of Tourism and Antiquities
# Arab Republic of Egypt

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': 'You are an tour guide assistant that analyzes the contents of egypt website and provides list of activeties, ignoring text that might be navigation related. Respond in markdown list .'},
#  {'role': 'user',
#   'content': "You are looking at a website titled \r\n            Experience Egypt\r\n        \nThe contents of this website is as follows; please provide a  list of activeties, in markdown list. If it includes news or announcements, then summarize these too.\n\nABOUT EGYPT\nThe land where it all begins\nThis is Egypt\nGeography\nHistory\nLanguage & culture\nWHERE TO GO\nFind Your Dream Destination\nThe Nile\nLearn more\nThe Red Sea\nLearn more\nThe Med\nLearn more\nDESERTS & OASES\nLearn more\nWHAT TO DO\nGet Ready for the Experience of a Lifetime\nSUN & SEA\nARCHEOLOGICAL SITES\nSPIRITUAL EGYPT\nMUSEUMS\nCRUISING & SAILING\nADVENTURE & OUTDOOR\nECOTOURISM & NATURE\nHEALTH & WELLNESS\nARTS & CONTEMPORARY CULTURE\nWHAT'S ON\nUpcoming  Events\nAlex Short Film Festival\n27\nApr\nAswan International Women Film\n2\nMay\nEye on Egypt\nVisiting The Temples Of Luxor? Stop By The Colossi Of Memnon\nRead More\nCulture And Beach Holidays In Egypt\nRead More\nUSEFUL INFORMATION\nGood to Know\nEntry visa\nPLAN YOUR TRIP\nPRACTICAL INFO\nTRAVEL SAFE\nGETTING AROUND\nHOW TO GET THERE\nUSEFUL NUMBERS\nABOUT EGYPT\n- THIS IS EGYPT\n- GEOGRAPHY\n- HISTORY\n- LANGUAGE & CULTURE\nWHERE TO GO\n- THE NILE\n- THE RED SEA\n- THE MED\n- DESERTS & OASES\nWHAT TO DO\n- SUN & SEA\n- ARCHEOLOGICAL SITES\n- SPIRITUAL EGYPT\n- MUSEUMS\n- CRUISING & SAILING\n- ADVENTURE & OUTDOOR\n- ECOTOURISM & NATURE\n- HEALTH & WELLNESS\n- ARTS & CONTEMPORARY CULTURE\nWHAT'S ON\n- EVENTS\n- NEWS\nUSEFUL INFORMATION\nENTRY VISA\nPLAN YOUR TRIP\nPRACTICAL INFO\nTRAVEL SAFE\nGETTING AROUND\nHOW TO GET THERE\nUSEFUL NUMBERS\nEnglish\nEnglish\n中文\nDeutsch\nРусский\nRecommended Places\nSharm El-Sheikh\nHome\nThis is Egypt
ollama-0.4.8-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\users\hanye\miniconda3\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\hanye\miniconda3\lib\site-packages (from ollama) (2.11.4)
# Requirement already satisfied: anyio in c:\users\hanye\miniconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (4.9.0)
# Requirement already satisfied: certifi in c:\users\hanye\miniconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\hanye\miniconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.0.7)
# Requirement already satisfied: idna in c:\users\hanye\miniconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hanye\miniconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hanye\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hanye\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\hanye\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hanye\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.4.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hanye\miniconda3\lib\site-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.3.1)
# Downloading ollama-0.4.8-py3-none-any.whl (13 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.4.8

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2:1b"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Creation and Marketing**: Generative AI can create high-quality, engaging content such as articles, social media posts, and product descriptions using natural language processing (NLP) and machine learning algorithms. This helps businesses to:
# 	* Automate content creation, reducing costs and increasing productivity.
# 	* Personalize content to target specific audience segments.
# 	* Enhance customer engagement through personalized messaging.
# 2. **Virtual Assistants**: Generative AI can power virtual assistants like chatbots, which can help businesses:
# 	* Provide 24/7 support to customers via voice or text.
# 	* Automate routine tasks and workflows.
# 	* Offer personalized recommendations and suggestions.
# 3. **Predictive Maintenance**: Generative AI can analyze sensor data from industrial equipment to predict maintenance needs, reducing downtime and increasing efficiency. This application is particularly useful in:
# 	* Manufacturing and logistics industries.
# 	* Oil and gas sectors.
# 4. **Quality Control and Inspection**: Generative AI can be used to inspect products for defects or imperfections, helping businesses:
# 	* Improve product quality control and reduction of defective products.
# 	* Automate the inspection process, reducing labor costs.
# 5. **Marketing Strategy Development**: Generative AI can help businesses:
# 	* Analyze customer data and preferences to develop targeted marketing strategies.
# 	* Create personalized marketing campaigns using NLP and machine learning algorithms.
# 6. **Transcription and Translation Services**: Generative AI can automate transcription and translation tasks, reducing costs and increasing efficiency. This application is particularly useful in:
# 	* Media and entertainment industries.
# 	* Academic research institutions.
# 7. **Design and Product Development**: Generative AI can assist designers and product developers by generating new design ideas or product prototypes, helping businesses:
# 	* Increase innovation and creativity.
# 	* Reduce design time and improve speed to market.
# 8. **Healthcare and Medical Research**: Generative AI can help healthcare professionals:
# 	* Analyze medical data to identify patterns and trends.
# 	* Develop personalized treatment plans using machine learning algorithms.
# 9. **Financial Analysis and Forecasting**: Generative AI can automate financial analysis and forecasting tasks, helping businesses:
# 	* Improve financial decision-making.
# 	* Reduce costs associated with manual data entry and analysis.
# 10. **Supply Chain Optimization**: Generative AI can help supply chain managers optimize logistics, transportation, and inventory management by analyzing real-time data from sensors and IoT devices.
#
# These are just a few examples of the business applications of generative AI. As this technology continues to evolve, we can expect to see even more innovative uses in various industries.

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has a wide range of business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can be used to create high-quality content, such as articles, social media posts, and product descriptions, that are tailored to specific audiences and goals.
# 2. **Digital Twinning**: Generative AI can help companies create digital replicas of physical assets, allowing for more efficient maintenance, optimization, and decision-making.
# 3. **Personalized Marketing**: By analyzing customer data and behavior, generative AI can be used to create personalized marketing campaigns that are more effective and engaging.
# 4. **Product Design**: Generative AI can assist designers in creating innovative product designs by generating ideas, prototypes, and even entire products.
# 5. **Supply Chain Optimization**: Generative AI can help companies optimize their supply chains by predicting demand, identifying bottlenecks, and suggesting optimal logistics routes.
# 6. **Customer Service Chatbots**: Generative AI-powered chatbots can be used to provide 24/7 customer support, answering frequently asked questions and routing complex issues to human agents.
# 7. **Automated Quality Control**: Generative AI can help companies monitor product quality in real-time, detecting defects and anomalies that may require human intervention.
# 8. **Virtual Research Assistants**: Generative AI-powered virtual research assistants can help researchers find relevant data, articles, and sources for their studies.
# 9. **Product Development**: Generative AI can assist designers and developers in creating new products, prototypes, and even entire product categories.
# 10. **Risk Management**: Generative AI can be used to simulate different scenarios and outcomes, helping companies prepare for potential risks and optimize their strategies.
#
# In various industries:
#
# * **Finance**: generative AI can help with risk management, predictive analytics, and portfolio optimization.
# * **Healthcare**: generative AI can assist in medical research, disease diagnosis, and personalized treatment planning.
# * **Retail**: generative AI can help with product recommendation, inventory management, and customer service chatbots.
# * **Education**: generative AI can create personalized learning experiences, adaptive assessments, and intelligent tutoring systems.
#
# These applications demonstrate the vast potential of Generative AI in transforming various aspects of business operations.

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative AI has a wide range of business applications across various industries. Here are some examples:
#
# 1. **Content creation**: Generative AI algorithms can create content such as text articles, social media posts, and product descriptions at an unprecedented scale and speed. This can help businesses stay competitive in the content-marketing space.
# 2. **Marketing automation**: Generative AI can be used to personalize customer interactions across multiple touchpoints, helping businesses improve customer experiences and increase loyalty.
# 3. **Design and creative development**: Generative AI can generate novel designs for products, services, or brand identities, such as logo suggestions, product prototypes, or even entire business strategies.
# 4. **Research and analytics**: Generative AI can help discover new insights and patterns in large datasets, assisting businesses with research, predictive modeling, and anomaly detection.
# 5. **Recommendation systems**: Generative AI algorithms can generate personalized recommendations for customers based on their preferences and browsing histories, improving the effectiveness of recommendation engines.
# 6. **Financial modeling**: Generative AI can create complex financial models, such as stress tests, scenario planning, or investment analysis, helping businesses make informed decisions about risk management and strategic investments.
# 7. **Product development**: Generative AI can assist in the design and prototyping of new products by generating concepts, simulations, and test results, reducing the time and cost associated with traditional product development methods.
# 8. **Sentiment analysis**: Generative AI-powered sentiment analysis tools can analyze vast amounts of text data to detect emotions, moods, and opinions, helping businesses better understand their customers' needs and preferences.
# 9. **Language translation**: Generative AI can be used to improve machine translation accuracy by generating high-quality translations from one language to another, breaking down language barriers in international markets.
# 10. **Risk assessment**: Generative AI can help evaluate the risks associated with business operations, such as market fluctuations, regulatory changes, or natural disasters, enabling businesses to make data-driven decisions and mitigate potential threats.
#
# Some of the key players in the business applications of generative AI include:
#
# 1. IBM
# 2. Google Cloud AI Lab
# 3. Microsoft Azure Machine Learning
# 4. NVIDIA Deep Learning Institute
# 5. H2O.ai
# 6. Talend
# 7. Apache Spark
# 8. Amazon SageMaker

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

# %%
import langchain ,langchain_core
dir(langchain_core.document_loaders )
# Out:
# ['BaseBlobParser',
#  'BaseLoader',
#  'Blob',
#  'BlobLoader',
#  'LangSmithLoader',
#  'PathLike']

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("F:/AI_APPS/Tourist_Assistant/Data/Egypt.pdf")
pages = []
async for page in loader.alazy_load():
    pages.append(page)

# %%
pages
# Out:
# [Document(metadata={'producer': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission; modified using iText® 5.2.0 ©2000-2012 1T3XT BVBA', 'creator': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission', 'creationdate': '2019-01-08T14:38:47+01:00', 'title': '', 'keywords': '', 'moddate': '2019-01-08T14:46:28+01:00', 'subject': '', 'author': '', 'source': 'F:/AI_APPS/Tourist_Assistant/Data/Egypt.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='II. PARTNER COUNTRY PROFILES – EGYPT\nOECD TOURISM TRENDS AND POLICIES 2018 © OECD 2018330\nEgypt\nTourism in the economy\nThe tourism industry, involving around 70 sub-sectors, has always been an important\neconomic activity in Egypt. Travel receipts constituted the sixth largest source of foreign\ncurrency with international tourists generating a total of USD 2.6 billion in revenue.\nTourism contributed (directly and indirectly) 11.3% of Egypt’s GDP in 2015/2016. It accounts\nfor 23% of total services exports.\nInternational tourist arrivals to Egypt reached 5.4 million visitors in 2016 (32.7 million\ntourist nights). About 12% of inbound tourists are from Germany, 19% from other Western\nEuropean countries, 15% from Eastern European countries and 36% from Arab countries.\nAccording to Egypt’s Tourism Satellite Account (TSA) for 2014, the labour force working\nin tourism stood at 1.8 million individuals, representing 6.3% of the total labour force and\n7.2% of total employment in Egypt. Around 74% of employees in tourism are full-time with\n26% working on a temporary basis or part-time.\nTourism governance and funding\nThe Ministry of Tourism is responsible for tourism policy and for establishing a\ncoherent legal and regulatory framework for tourism development. T wo tourism\nauthorities fall under the Ministry:\n● The Tourism Development Authority works primarily on setting and implementing\nregulations for tourism projects and investments, by assisting with the provision of land\nand facilitating access to loans for developing infrastructure projects,\n● The Egyptian Tourism Authority (ETA) is responsible for promoting inbound and\ndomestic tourism. It manages the development and diversification of the tourism\nproduct, both regionally and internationally.\nThe Egyptian Tourism Federation (ETF) is composed of five tourism industry business\nassociations – the Hotels Association, the Travel Agents’ Association, the Chamber of\nTourist Establishments, the Chamber of Tourist Commodities and the Chamber of Diving\nand Water Sports. It works closely with the Ministry of Tourism in areas related to tourism\nplanning, and in managing the Tourism Workforce Skills Development Project. By law, the\nETF’s views are considered before any new legislative measures are taken.\nThe Ministry recognises the need to support coordination with other ministries and\ninstitutions for effective tourism policy and is working to improve co-operation among all\nrelevant stakeholders. To assist in this process, the Ministry has adopted a concept of\ndecentralisation in tourism to ease communication between the government and the\nprivate sector, implemented effective structures for the management and development of\ntourism activity, adapted laws and regulations to attract investment, maintained the\nRef. Ares(2019)84234 - 08/01/2019'),
#  Document(metadata={'producer': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission; modified using iText® 5.2.0 ©2000-2012 1T3XT BVBA', 'creator': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission', 'creationdate': '2019-01-08T14:38:47+01:00', 'title': '', 'keywords': '', 'moddate': '2019-01-08T14:46:28+01:00', 'subject': '', 'author': '', 'source': 'F:/AI_APPS/Tourist_Assistant/Data/Egypt.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='II. PARTNER COUNTRY PROFILES – EGYPT\nOECD TOURISM TRENDS AND POLICIES 2018 © OECD 2018 331\nstability of private sector participation (represented by the ETF and its five chambers) by\nstrengthening relations with tourism clusters such as investor associations and tourism\ncommittees in the chambers of commerce, and sought to provide regular, accurate and\ntransparent data.\nThe Supreme Council for Tourism helps to fast track progress by removing barriers. It\ninvolves eleven ministries and the ETF, and is chaired by the President.\nThe general budget for tourism promotion is around USD 67 million which is directed\ntowards external activities including: launching a new branding campaign over the next\nthree years for global marketing, setting up interactive advertising in touristic sites,\nenhancing public relations and optimising search engines. These activities are managed by\nthe ETA and financed by the Tourism Fund Unit at the Ministry. The Accountability State\nAuthority (ASA), an external government agency, monitors and evaluates the fund\nexpenditure to ensure a transparent process.\nTourism policies and programmes\nEgypt’s national strategy considers tourism as an important national industry and\nseeks to create a suitable environment to support tourism. Tourism faces many challenges\nand new policies have to be set to enhance a competitive, sustainable and inclusive\ntourism industry. Such challenges include:\n● Infrastructure: restrictions on charter airlines, the railways etc.,\n● Workforce: qualification gaps, the need for “on the job” training, technology skills and\ncertified instructors, technical education and vocational training, and quality of service,\n● Complex legislative and licensing frameworks: the new Tourism Law is yet to be\nimplemented,\n● Safety and security: hygiene, traffic safety, emergency systems, hotel standards, public\nsecurity and tourism awareness,\n● Marketing and promotion: branding and public relations,\n● Sustainability issues: energy efficiency, the use of solar and renewable energy sources,\nwater consumption, biodiversity, solid/liquid waste and carbon emissions.\nEgypt: Organisational chart of tourism bodies\nSource: OECD, adapted from Ministry of Tourism, 2018.\nEgyptian Tourism \nFederation              \n(ETF) \nMinistry of Tourism \nEgyptian Tourism \nAuthority                     \n(ETA) \nTourism Development \nAuthority (TDA) \nResearch and \nPlanning \nHotels and Tourism \nEstablishments \nEgyptian Hotels \nAssociation \nTechnical \nDirectorate \nEgyptian Travel \nAgents Association \nTourism Companies \nand Guides Office of the Minister \nChamber of Diving \nand Water Sports \nEgyptian Chamber of \nTourist Commodities \nEgyptian Chamber     \nof Tourist \nEstablishments \nTourism Activities and \nInternal Offices'),
#  Document(metadata={'producer': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission; modified using iText® 5.2.0 ©2000-2012 1T3XT BVBA', 'creator': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission', 'creationdate': '2019-01-08T14:38:47+01:00', 'title': '', 'keywords': '', 'moddate': '2019-01-08T14:46:28+01:00', 'subject': '', 'author': '', 'source': 'F:/AI_APPS/Tourist_Assistant/Data/Egypt.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='II. PARTNER COUNTRY PROFILES – EGYPT\nOECD TOURISM TRENDS AND POLICIES 2018 © OECD 2018332\nThe sustainable tourism strategy is currently being revised with new targets for 2030.\nThe priorities are to increase value, to achieve high and sustainable economic growth,\nalleviate poverty, address income disparities, create productive jobs and increase gender\nequality. The strategic targets are to:\n● Attract 20 million international arrivals,\n● Raise the average tourist expenditure per night by 50%,\n● Increase Egypt’s share of world tourism to 1.5%,\n● Double Egypt’s share of Arab tourism,\n● Raise tourism revenues to USD 20 billion,\n● Attract USD 10 billion of new foreign direct investment in tourism.\nThe strategy seeks to address the challenges and achieve its targets through landmark\nreforms and investments. Initiatives include:\n● Institutional change: Establishing the Tourism Development Authority and Ministry of\nTourism as a one-stop-shop for licenses and permits, developing an intranet system\nlinking hotels, chambers and the Ministry, and establishing an advisory committee of\nexperts headed by the minister.\n● Connectivity: Providing a new entry regime for many source markets with an E-visa\nsystem and support for the private sector when establishing new routes or enhancing\nfrequency for travel.\n● Marketing and promotion: Presenting products and services in strategic markets using\ninnovative and smart techniques including, a new marketing website with 14 languages,\nan online campaign in traditional markets and China and India, better management of\nsocial media, working with bloggers, a new cultural tourism commercial, and promotion\nof the new VAT refund system. These activities will support traditional promotion and\nmarketing tools.\n● Investment: Developing and diversifying tourism products and services, responding to\ncustomer needs and trends, building high quality visitor experiences, developing a\nstrong sense of place and style for Egypt and for the five internal destinations.\n● Sustainability: Establishing eco-principles and a “green” tourism unit, heritage preservation,\na “Green Star Hotel” programme monitoring the transformation of hotels to\nenvironmentally friendly management and efforts to enhance environmental awareness\nin the sector.\n● Workforce: Promoting a National Skill Standards Project, a culinary training centre,\nenhanced capacities in tourism establishments, and an accreditation and certification\nsystem.\nEgypt will apply the principles of social inclusion in its approach to tourism. It will\ntarget the citizens and communities of Egypt as primary beneficiaries by providing\nopportunities for employment and income generation, by positively contributing to\ngovernment programs, by supporting quality of life and environmental excellence and by\ndeveloping communities and society. Investments should cover skill development and\ntraining to enhance human resource development and capacity building across the sector.'),
#  Document(metadata={'producer': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission; modified using iText® 5.2.0 ©2000-2012 1T3XT BVBA', 'creator': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission', 'creationdate': '2019-01-08T14:38:47+01:00', 'title': '', 'keywords': '', 'moddate': '2019-01-08T14:46:28+01:00', 'subject': '', 'author': '', 'source': 'F:/AI_APPS/Tourist_Assistant/Data/Egypt.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'
. ..\nTourism industries .. 1 706 700 1 698 800 1 752 000 1 992 665 ..\nAccommodation services for visitors 1 239 166 900 156 900 156 100 188 740 ..\nHotels and similar establishments .. .. .. .. .. ..\nFood and beverage serving industry 1 300 366 000 382 400 408 600 488 240 ..\nPassenger transport .. 1 026 500 1 020 500 1 06 8 000 1 175 486. .\nAir passenger transport .. 34 500 28 600 24 000 23 710 ..\nRailways passenger transport .. 63 500 60 100 66 000 55 970 ..\nRoad passenger transport .. 914 000 927 600 968 000 1 078 428 ..\nWater passenger transport .. 14 500 4 200 10 000 17 37 8 ..\nPassenger transport supporting services .. .. .. .. .. ..\nTransport equipment rental .. 2 300 2 200 1 000 4 151 ..\nTravel agencies and other reservation services \nindustry 18 525 70 100 58 200 48 000 63 167 ..\nCultural industry .. 14 400 13 500 12 700 1 8 251 ..\nSports and recreation industry .. 31 200 34 500 26 000 31 290 ..\nRetail trade of country-specific tourism \ncharacteristic goods .. 12 500 12 700 13 000 22 897 ..\nOther country-specific tourism industries .. 16 800 17 900 18 600 481 ..\nOther industries .. .. .. .. .. ..\n.. Not available\nSource: OECD Tourism Statistics (Database).\n2014\nDomestic tourism expenditure Inbound tourism expenditure Internal tourism consumption\nTotal 22 096 98 112 138 737\nConsumption products 22 096 95 075 135 700\nTourism characteristic products 14 295 80 171 112 995\nAccommodation services for visitors 2 177 12 791 29 567\nFood and beverage serving services 3 807 26 399 30 578\nPassenger transport services 6 575 17 3 88 27 167\nAir passenger transport services 4 426 9 808 14 864\nRailways passenger transport services 296 893 9 1\nRoad passenger transport services 1 839 6 233 8 736\nWater passenger transport services 14 1 258 3 176\nPassenger transport supporting services .. .. ..\nTransport equipment rental services .. 297 297\nTravel agencies and other reservation services \nindustry 1 006 5 770 6 776\nCultural services 103 3 8 08 4 170\nSports and recreation services 532 7 398 8 026\nCountry-specific tourism characteristic goods 96 5 097 5 193\nCountry-specific tourism characteristic services .. 1 224 1 224\nOther consumption products 7 801 14 904 22 705\nTourism connected products .. .. ..\nNon-tourism related consumption products .. .. ..\nNon-consumption products .. 3 037 3 037'),
#  Document(metadata={'producer': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission; modified using iText® 5.2.0 ©2000-2012 1T3XT BVBA', 'creator': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission', 'creationdate': '2019-01-08T14:38:47+01:00', 'title': '', 'keywords': '', 'moddate': '2019-01-08T14:46:28+01:00', 'subject': '', 'author': '', 'source': 'F:/AI_APPS/Tourist_Assistant/Data/Egypt.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='From:\nOECD Tourism Trends and Policies 2018\nAccess the complete publication at:\nhttps://doi.org/10.1787/tour-2018-en\nPlease cite this chapter as:\nOECD (2018), “Egypt”, in OECD Tourism Trends and Policies 2018, OECD Publishing, Paris.\nDOI: https://doi.org/10.1787/tour-2018-48-en\nThis work is published under the responsibility of the Secretary-General of the OECD. The opinions expressed and arguments\nemployed herein do not necessarily reflect the official views of OECD member countries.\nThis document and any map included herein are without prejudice to the status of or sovereignty over any territory, to the\ndelimitation of international frontiers and boundaries and to the name of any territory, city or area.\nYou can copy, download or print OECD content for your own use, and you can include excerpts from OECD publications,\ndatabases and multimedia products in your own documents, presentations, blogs, websites and teaching materials, provided\nthat suitable acknowledgment of OECD as source and copyright owner is given. All requests for public or commercial use and\ntranslation rights should be submitted to rights@oecd.org. Requests for permission to photocopy portions of this material for\npublic or commercial use shall be addressed directly to the Copyright Clearance Center (CCC) at info@copyright.com or the\nCentre français d’exploitation du droit de copie (CFC) at contact@cfcopies.com.')]

# %%
print(f"{pages[0].metadata}\n")
print(pages[0].page_content)
# Out:
# {'producer': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission; modified using iText® 5.2.0 ©2000-2012 1T3XT BVBA', 'creator': 'OCR CoDe 2017 3.6337.6337 (c) 2005-2017 European Commission', 'creationdate': '2019-01-08T14:38:47+01:00', 'title': '', 'keywords': '', 'moddate': '2019-01-08T14:46:28+01:00', 'subject': '', 'author': '', 'source': 'F:/AI_APPS/Tourist_Assistant/Data/Egypt.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}
#
# II. PARTNER COUNTRY PROFILES – EGYPT
# OECD TOURISM TRENDS AND POLICIES 2018 © OECD 2018330
# Egypt
# Tourism in the economy
# The tourism industry, involving around 70 sub-sectors, has always been an important
# economic activity in Egypt. Travel receipts constituted the sixth largest source of foreign
# currency with international tourists generating a total of USD 2.6 billion in revenue.
# Tourism contributed (directly and indirectly) 11.3% of Egypt’s GDP in 2015/2016. It accounts
# for 23% of total services exports.
# International tourist arrivals to Egypt reached 5.4 million visitors in 2016 (32.7 million
# tourist nights). About 12% of inbound tourists are from Germany, 19% from other Western
# European countries, 15% from Eastern European countries and 36% from Arab countries.
# According to Egypt’s Tourism Satellite Account (TSA) for 2014, the labour force working
# in tourism stood at 1.8 million individuals, representing 6.3% of the total labour force and
# 7.2% of total employment in Egypt. Around 74% of employees in tourism are full-time with
# 26% working on a temporary basis or part-time.
# Tourism governance and funding
# The Ministry of Tourism is responsible for tourism policy and for establishing a
# coherent legal and regulatory framework for tourism development. T wo tourism
# authorities fall under the Ministry:
# ● The Tourism Development Authority works primarily on setting and implementing
# regulations for tourism projects and investments, by assisting with the provision of land
# and facilitating access to loans for developing infrastructure projects,
# ● The Egyptian Tourism Authority (ETA) is responsible for promoting inbound and
# domestic tourism. It manages the development and diversification of the tourism
# product, both regionally and internationally.
# The Egyptian Tourism Federation (ETF) is composed of five tourism industry business
# associations – the Hotels Association, the Travel Agents’ Association, the Chamber of
# Tourist Establishments, the Chamber of Tourist Commodities and the Chamber of Diving
# and Water Sports. It works closely with the Ministry of Tourism in areas related to tourism
# planning, and in managing the Tourism Workforce Skills Development Project. By law, the
# ETF’s views are considered before any new legislative measures are taken.
# The Ministry recognises the need to support coordination with other ministries and
# institutions for effective tourism policy and is working to improve co-operation among all
# relevant stakeholders. To assist in this process, the Ministry has adopted a concept of
# decentralisation in tourism to ease communication between the government and the
# private sector, implemented effective structures for the management and development of
# tourism activity, adapted laws and regulations to attract investment, maintained the
# Ref. Ares(2019)84234 - 08/01/2019

# %%
import getpass
import os

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")

# %%
from langchain_core.vectorstores import InMemoryVectorStore
from langchain_openai import OpenAIEmbeddings

vector_store = InMemoryVectorStore.from_documents(pages, OpenAIEmbeddings())
docs = vector_store.similarity_search(" Tourism in the economy?", k=2)
for doc in docs:
    print(f'Page {doc.metadata["page"]}: {doc.page_content[:300]}\n')
# Out:
# Page 0: II. PARTNER COUNTRY PROFILES – EGYPT
# OECD TOURISM TRENDS AND POLICIES 2018 © OECD 2018330
# Egypt
# Tourism in the economy
# The tourism industry, involving around 70 sub-sectors, has always been an important
# economic activity in Egypt. Travel receipts constituted the sixth largest source of foreign
# curre
#
# Page 4: II. PARTNER COUNTRY PROFILES – EGYPT
# OECD TOURISM TRENDS AND POLICIES 2018 © OECD 2018334
# Table 2. Egypt: Enterprises and employment in tourism
# 1 2 http://dx.doi.org/10.1787/888933641887
# Table 3. Egypt: Internal tourism consumption
# Million EGP
# 1 2 http://dx.doi.org/10.1787/888933641906
# .. Not availa

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

file_path = "F:/AI_APPS/Tourist_Assistant/Notebooks/cairo_restaurants_cleaned.csv"

loader = CSVLoader(
    file_path=file_path,
    csv_args={"delimiter": ",", "quotechar": '"'},
    encoding="utf-8"
)
data = loader.load()

for record in data[:2]:
    print(record)
# Out:
# page_content='uuid: dca9674273a7576fe3efa7e28e5c7813eb40265f373fa73da5d66d98f83cbdfa
# poi_name: Sultan Restaurant
# lat: 29.540509
# lng: 30.979346
# reviews_no: 1.0
# price_range:
# category: Restaurant' metadata={'source': 'F:/AI_APPS/Tourist_Assistant/Notebooks/cairo_restaurants_cleaned.csv', 'row': 0}
# page_content='uuid: 91ac51e8b236ac6a7f2c29edd6410d9c7624f68afb99e4b0083a978aca604a20
# poi_name: مطعم ع الصاج
# lat: 29.5397456
# lng: 30.9792021
# reviews_no: 2.0
# price_range:
# category: Restaurant' metadata={'source': 'F:/AI_APPS/Tourist_Assistant/Notebooks/cairo_restaurants_cleaned.csv', 'row': 1}

# %%
import requests

query = "langchain vs llamaindex"
url = "https://api.duckduckgo.com/"

params = {
    "q": query,
    "format": "json",
    "no_redirect": 1,
    "no_html": 1,
    "skip_disambig": 1
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print("Abstract:", data.get("AbstractText", "No summary available"))
    print("URL:", data.get("AbstractURL", "No URL available"))
else:
    print("Error:", response.status_code)
# Out:
# Abstract:
# URL:

# %%
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model=MODEL)

llm.invoke("The first man on the moon was ...")
# Out:
# 'Neil Armstrong was indeed the first person to walk on the moon. On July 20, 1969, he became the first human to set foot on the lunar surface during the Apollo 11 mission. He famously declared, "That\'s one small step for man, one giant leap for mankind," as he stepped out of the lunar module Eagle onto the moon\'s surface.'

# %%
from langchain_ollama import OllamaLLM
llm = OllamaLLM(model='command-r7b-arabic')

llm.invoke("من اول رجل على سطح القمر كان ...")
# Out:
# 'نيل أرمسترونغ'
